# %% [markdown]
# # ✏️ Practice 3: 자료구조
#
# **Step 3: Data Structures** 에서 배운 개념을 연습하는 노트북입니다.
#
# - 각 문제를 직접 풀어보세요
# - 정답은 주석을 해제하여 확인할 수 있습니다
# - 막히면 Step3 노트북의 이론 파트를 참고하세요

# %% [markdown]
# ### ✏️ 실습: 과일 리스트 CRUD 관리
#
# 아래 조건에 따라 과일 리스트를 관리하세요.
#
# 1. `["사과", "바나나", "딸기"]` 리스트를 만드세요
# 2. `"포도"`를 맨 뒤에 추가하세요
# 3. `"키위"`를 두 번째 위치(인덱스 1)에 삽입하세요
# 4. `"바나나"`를 삭제하세요
# 5. 리스트를 가나다순(오름차순)으로 정렬하세요
# 6. 최종 리스트와 길이를 출력하세요
# 7. `"망고"`가 리스트에 있는지 확인하세요

# %%
# ──────────────────────────────────────
# ✏️ 실습: 과일 리스트 CRUD 관리
# ──────────────────────────────────────

# 여기에 코드를 작성하세요


# --- 정답 (확인 후 주석 해제) ---
# fruits = ["사과", "바나나", "딸기"]
# print("1. 초기 리스트:", fruits)
#
# fruits.append("포도")
# print("2. 포도 추가:", fruits)
#
# fruits.insert(1, "키위")
# print("3. 키위 삽입:", fruits)
#
# fruits.remove("바나나")
# print("4. 바나나 삭제:", fruits)
#
# fruits.sort()
# print("5. 정렬:", fruits)
#
# print(f"6. 최종 리스트: {fruits}, 길이: {len(fruits)}")
#
# print(f"7. '망고' 포함 여부: {'망고' in fruits}")

# %% [markdown]
# ### ✏️ 실습: 튜플 활용과 리스트 중복 제거
#
# **문제 1: 좌표 표현**
# 1. 세 점의 좌표를 튜플로 만드세요: A(1, 2), B(4, 6), C(7, 3)
# 2. 각 좌표를 언패킹하여 `x, y` 변수로 받으세요
# 3. 세 점의 x좌표 평균과 y좌표 평균을 구하세요
#
# **문제 2: 리스트 중복 제거**
# 1. 리스트 `[3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]`에서 중복을 제거하세요
# 2. 중복 제거 후 오름차순 정렬하여 출력하세요

# %%
# ──────────────────────────────────────
# ✏️ 실습: 튜플 활용과 리스트 중복 제거
# ──────────────────────────────────────

# 여기에 코드를 작성하세요


# --- 정답 (확인 후 주석 해제) ---
# # 문제 1: 좌표 표현
# A = (1, 2)
# B = (4, 6)
# C = (7, 3)
#
# ax, ay = A
# bx, by = B
# cx, cy = C
#
# avg_x = (ax + bx + cx) / 3
# avg_y = (ay + by + cy) / 3
# print(f"x좌표 평균: {avg_x:.1f}")
# print(f"y좌표 평균: {avg_y:.1f}")
#
# # 문제 2: 리스트 중복 제거
# numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# unique_sorted = sorted(set(numbers))
# print(f"중복 제거 + 정렬: {unique_sorted}")

# %% [markdown]
# ### ✏️ 실습: 전화번호부 만들기
#
# 딕셔너리를 활용하여 간단한 전화번호부를 관리하세요.
#
# 1. 전화번호부에 3명의 연락처를 등록하세요 (이름: 전화번호)
# 2. 새로운 연락처 1명을 추가하세요
# 3. 기존 연락처 1명의 번호를 수정하세요
# 4. `get()` 메서드로 특정 이름을 검색하세요 (있는 이름 1개, 없는 이름 1개)
# 5. 연락처 1명을 삭제하세요
# 6. `items()`를 사용하여 전체 전화번호부를 보기 좋게 출력하세요

# %%
# ──────────────────────────────────────
# ✏️ 실습: 전화번호부 만들기
# ──────────────────────────────────────

# 여기에 코드를 작성하세요


# --- 정답 (확인 후 주석 해제) ---
# # 1. 초기 전화번호부
# phonebook = {
#     "김민수": "010-1234-5678",
#     "이지영": "010-9876-5432",
#     "박현우": "010-5555-1234"
# }
# print("1. 초기 전화번호부:", phonebook)
#
# # 2. 추가
# phonebook["최수현"] = "010-7777-8888"
# print("2. 추가 후:", phonebook)
#
# # 3. 수정
# phonebook["김민수"] = "010-1111-2222"
# print("3. 수정 후:", phonebook)
#
# # 4. 검색
# print(f"4-1. 이지영: {phonebook.get('이지영', '등록되지 않음')}")
# print(f"4-2. 홍길동: {phonebook.get('홍길동', '등록되지 않음')}")
#
# # 5. 삭제
# del phonebook["박현우"]
# print("5. 삭제 후:", phonebook)
#
# # 6. 전체 출력
# print("\n6. 전체 전화번호부:")
# print("-" * 30)
# for name, number in phonebook.items():
#     print(f"  {name}: {number}")
# print("-" * 30)
# print(f"총 {len(phonebook)}명 등록")
